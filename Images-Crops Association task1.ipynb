# %% [markdown]
# ### Image_Association_Prediction
# In this approach, I have taken two sample images from the cropped and original. By applying TM_CCOEFF_NORMED technique , which simply slides the cropped image over the original image (as in 2D convolution) and compares the cropped and patch of original image under the cropped image
#
# So I chose OpenCV's matchTemplate functionality for this. The matchTemplate() function is fast and easy to use, usually yields robust results. There are 6 different matching algorithms we can use with this function.
#
#     TM_CCOEFF
#     TM_CCOEFF_NORMED
#     TM_CCORR
#     TM_CCORR_NORMED
#     TM_SQDIFF
#     TM_SQDIFF_NORMED
#
# All the _NORMED methods give output as a normalized value between 0.0 to 1.0. In TM_CCOEFF and TM_CCORR, maximum value corresponds to high probability of match, while in TM_SQDIFF_NORMED minimum value corresponds to high probability of a match. I chose TM_CCOEFF_NORMED since it gave consistent result with few of the matches I tested and it produces results in the range of 0.0 to 1.0, so that thresholding can be applied.

# %% [markdown]
# ### Assumptions
# I have made the following assumptions before proceeding the task
#
#     1.Crops folder contains cropped patches from the Images folder
#     2.Cropped images are not rotated. But they are resized while maintaining aspect ratio
#     3.Duplicate images may be found in both crops and images folders
#     4.Accuracy preferred over Speed
#     5.Usage of OpenCV's inbuilt functions as they are more reliable androbust
#     6.Sobel edge detector was not used before matching, since it didn't make any significant difference in multiple tests

# %% [markdown]
# ### Approach
#
# Approach I have followed:
#
#     1.Get original images in an array
#     2.Load the original image and cropped image
#     3.Apply little bit of Gaussian Blur to the images to remove noise
#     4.For different sizes of given template,
#     5.Use cv2.matchTemplate to match the image and template
#     6.Get the top-left and bottom-right corners and maximum match value
#     7.Compare the max value against the last obtained max value
#     8.If max value greater than last-max-value, insert maxvalue and coordinates in queue
#     9.Else return the last obtained max value along with coordinates
#     10.Apply thresholding, return the values if max value is greater than the threshold
#     11.Append the template name and coordinates to the dictionary
#     12.Repeat steps 1-5 for the all the images
#     13.Finally return the dictionary containing the output

# %% [markdown]
# ### Importing required libraries

# %%
# Uncomment code to download libraries
# !pip install opencv-python
# !pip install natsort
import os
import cv2
import glob
import re
import urllib.request
import numpy as np
from natsort import natsorted,ns
import json

# %% [markdown]
# ## Functions used in the main code
# Function :	                     Description
#
# **md5**:	                 Returns md5 checksum of the file
#
# **getUniqueCrops** 	:       Returns hash dict of unique crops filenames
#
# **matchCrop** 	 :            Does the template matching, returns -1 if no match found
#
# **getCropsAssociation**   : 	Helper function to pass images and crops to matcher function

# %%
numbers = re.compile(r'(\d+)')
print(numbers)
def numericalSort(value):
    parts = numbers.split(value)
    parts[1::2] = map(int, parts[1::2])
    print(parts)
    return parts

# %% [markdown]
# ### Template Matching
#
#
# Now I pass the image and template to matchTemplate() function. The matchTemplate() function takes the template and slides it over the original image pixel by pixel and calculates the match. The function returns a 2D array containing the value of matches at each position of the template over original image.
# #### The cv2.matchTemplate Trick
#
# In this case, all you need to do is apply a little trick:
#
#     1.Loop over the input image at multiple scales (i.e. make the input image progressively smaller and smaller).
#
#     2.Apply template matching using cv2.matchTemplate  and keep track of the match with the largest correlation coefficient (along with the x, y-coordinates of the region with the largest correlation coefficient).
#
#     3.After looping over all scales, take the region with the largest correlation coefficient and use that as your “matched” region.

# %%
def matchCrop(img,crop,threshold=0.8):
    if threshold > 1.0 or threshold < 0.0:
        return -1    
    
    img = cv2.GaussianBlur(img,(5,5),0)
    crop = cv2.GaussianBlur(crop,(5,5),0)
    
    ih,iw = img.shape[:2]
    h,w = crop.shape[:2]
    
    if ih//h > 8 or iw//w > 8:
        return -1
    
    q = collections.deque([[-2,0,0],[-2,0,0]],2)

    if iw/ih > w/h :
        crop = cv2.resize(crop,(int(w*ih/h),ih))
    else:
        crop = cv2.resize(crop,(iw,int(h*iw/w)))

    for scale in range(20):

        h,w = crop.shape[:2]

        if ih//h > 8 or iw//w > 8:
            break

        res = cv2.matchTemplate(img,crop,cv2.TM_CCOEFF_NORMED)

        _, max_val, _, max_loc = cv2.minMaxLoc(res)
        bottom_right = (max_loc[0]+w , max_loc[1]+h)

        if max_val > q[-1][0]:
            if max_val > threshold:
                q.append([max_val,max_loc,bottom_right])
        else:
            break

        h = int(h*0.86)
        w = int(w*0.86)
        crop = cv2.resize(crop,(w,h))
        
    if q[-1][0] > threshold:
        return q[-1]
    else:
        return -1

# %%
# Returns md5 checksum of the file 
def md5(fname):
    hash_md5 = hashlib.md5()
    with open(fname, "rb") as f:
        for chunk in iter(lambda: f.read(4096), b""):
            hash_md5.update(chunk)
    return hash_md5.hexdigest()

# %%
#  Returns hash dict of unique crops filenames
def getUniqueCrops(crops_path):
    
    unique = {}
    for fname in glob.glob(crops_path):
        checksum = md5(fname)
        if checksum in unique:
            unique[checksum].append(fname)
        else:
            unique[checksum] = [fname]
            
    return unique
# Helper function to pass images and crops to matcher function
def getCropsAssociation(im_path,keys):
    
    matches = []    
    im = cv2.imread(im_path)

    for key in keys:
        cr = cv2.imread(unique_crops[key][0])
        result = matchCrop(im,cr)

        if result != -1:
            max_val,top_left,bottom_right = result
            
            if key not in found_crops:
                found_crops.append(key)
                
            for val in unique_crops[key]:
                crop_name = val.split('/')[1]
                matches.append((crop_name,[top_left[0],top_left[1],bottom_right[0],bottom_right[1]]))
    
    return matches

# %%
import hashlib
import collections
import time
import glob
import hashlib
CROPS_PATH = 'Cropped Images/'
IMAGES_PATH = 'Real Images/'

found_crops = []
not_found = []
match_dict = {}

unique_crops = getUniqueCrops(CROPS_PATH+'*')
keys = unique_crops.keys()

t1 = time.time()

images = [path.split('/')[1] for path in glob.glob(IMAGES_PATH+'*')]

for image_name in images:
    print(IMAGES_PATH+image_name)
    match_dict[image_name] = getCropsAssociation(IMAGES_PATH+image_name,keys)

for key in keys:
    if key not in found_crops:
        cr_names = []
        for path in unique_crops[key]:
            not_found.append((path.split('/')[1],[]))
            
match_dict['na'] = not_found

t2 = time.time()

print(t2-t1," secs")
# Out:
# Real Images/image_name_139.jpg
# Real Images/image_name_101.jpg
# Real Images/image_name_49.jpg
# Real Images/image_name_55.jpg
# Real Images/image_name_39.jpg
# Real Images/image_name_132.jpg
# Real Images/image_name_64.jpg
# Real Images/image_name_137.jpg
# Real Images/image_name_69.jpg
# Real Images/image_name_70.jpg
# Real Images/image_name_92.jpg
# Real Images/image_name_99.jpg
# Real Images/image_name_16.jpg
# Real Images/image_name_31.jpg
# Real Images/image_name_14.jpg
# Real Images/image_name_111.jpg
# Real Images/image_name_54.jpg
# Real Images/image_name_124.jpg
# Real Images/image_name_142.jpg
# Real Images/image_name_108.jpg
# Real Images/image_name_67.jpg
# Real Images/image_name_50.jpg
# Real Images/image_name_104.jpg
# Real Images/image_name_40.jpg
# Real Images/image_name_71.jpg
# Real Images/image_name_12.jpg
# Real Images/image_name_13.jpg
# Real Images/image_name_96.jpg
# Real Images/image_name_15.jpg
# Real Images/image_name_5.jpg
# Real Images/image_name_37.jpg
# Real Images/image_name_68.jpg
# Real Images/image_name_21.jpg
# Real Images/image_name_74.jpg
# Real Images/image_name_30.jpg
# Real Images/image_name_140.jpg
# Real Images/image_name_2.jpg
# Real Images/image_name_38.jpg
# Real Images/image_name_123.jpg
# Real Images/image_name_86.jpg
# Real Images/image_name_23.jpg
# Real Images/image_name_95.jpg
# Real Images/image_name_100.jpg
# Real Images/image_name_98.jpg
# Real Images/image_name_60.jpg
# Real Images/image_name_61.jpg
# Real Images/image_name_32.jpg
# Real Images/image_name_82.jpg
# Real Images/image_name_27.jpg
# Real Images/image_name_57.jpg
# Real Images/image_name_34.jpg
# 15865.912796020508  secs

# %% [markdown]
# ## Result

# %%
match_dict
# Out:
# {'image_name_139.jpg': [('crop_name_201.jpg', [0, 0, 400, 387]),
#   ('crop_name_53.jpg', [0, 0, 400, 343]),
#   ('crop_name_0.jpg', [0, 0, 400, 402]),
#   ('crop_name_94.jpg', [0, 0, 400, 438]),
#   ('crop_name_37.jpg', [0, 0, 400, 409]),
#   ('crop_name_188.jpg', [0, 0, 400, 376]),
#   ('crop_name_147.jpg', [0, 0, 400, 319]),
#   ('crop_name_31.jpg', [0, 0, 400, 326]),
#   ('crop_name_306.jpg', [4, 299, 49, 367]),
#   ('crop_name_142.jpg', [0, 0, 400, 356]),
#   ('crop_name_179.jpg', [0, 0, 400, 426]),
#   ('crop_name_265.jpg', [0, 0, 400, 523]),
#   ('crop_name_258.jpg', [0, 0, 400, 440]),
#   ('crop_name_144.jpg', [0, 0, 400, 493]),
#   ('crop_name_307.jpg', [0, 125, 400, 502]),
#   ('crop_name_48.jpg', [0, 0, 400, 430]),
#   ('crop_name_305.jpg', [0, 0, 400, 473]),
#   ('crop_name_9.jpg', [0, 0, 400, 341]),
#   ('crop_name_195.jpg', [0, 0, 400, 436])],
#  'image_name_101.jpg': [('crop_name_201.jpg', [0, 0, 400, 387]),
#   ('crop_name_53.jpg', [0, 0, 400, 343]),
#   ('crop_name_0.jpg', [0, 0, 400, 402]),
#   ('crop_name_94.jpg', [0, 0, 400, 438]),
#   ('crop_name_37.jpg', [0, 0, 400, 409]),
#   ('crop_name_188.jpg', [0, 0, 400, 376]),
#   ('crop_name_147.jpg', [0, 0, 400, 319]),
#   ('crop_name_31.jpg', [0, 0, 400, 326]),
#   ('crop_name_142.jpg', [0, 0, 400, 356]),
#   ('crop_name_179.jpg', [0, 0, 400, 426]),
#   ('crop_name_265.jpg', [0, 0, 400, 523]),
#   ('crop_name_258.jpg', [0, 0, 400, 440]),
#   ('crop_name_144.jpg', [0, 0, 400, 493]),
#   ('crop_name_307.jpg', [36, 31, 380, 355]),
#   ('crop_name_48.jpg', [0, 0, 400, 430]),
#   ('crop_name_305.jpg', [0, 0, 400, 473]),
#   ('crop_name_9.jpg', [0, 0, 400, 341]),
#   ('crop_name_195.jpg', [0, 0, 400, 436]),
#   ('crop_name_148.jpg', [132, 382, 183, 463])],
#  'image_name_49.jpg': [('crop_name_201.jpg', [0, 0, 400, 387]),
#   ('crop_name_53.jpg', [0, 0, 400, 343]),
#   ('crop_name_0.jpg', [0, 0, 400, 402]),
#   ('crop_name_93.jpg', [106, 319, 185, 496]),
#   ('crop_name_94.jpg', [0, 0, 400, 438]),
#   ('crop_name_37.jpg', [0, 0, 400, 409]),
#   ('crop_name_188.jpg', [0, 0, 400, 376]),
#   ('crop_name_147.jpg', [0, 0, 400, 319]),
#   ('crop_name_156.jpg', [80, 256, 190, 536]),
#   ('crop_name_31.jpg', [0, 0, 400, 326]),
#   ('crop_name_306.jpg', [104, 391, 149, 459]),
#   ('crop_name_142.jpg', [0, 0, 400, 356]),
#   ('crop_name_179.jpg', [0, 0, 400, 426]),
#   ('crop_name_265.jpg', [0, 0, 400, 523]),
#   ('crop_name_258.jpg', [0, 0, 400, 440]),
#   ('crop_name_144.jpg', [0, 0, 400, 493]),
#   ('crop_name_307.jpg', [0, 24, 400, 401]),
#   ('crop_name_48.jpg', [0, 0, 400, 430]),
#   ('crop_name_305.jpg', [0, 0, 400, 473]),
#   ('crop_name_9.jpg', [0, 0, 400, 341]),
#   ('crop_name_195.jpg', [0, 0, 400, 436])],
#  'image_name_55.jpg': [('crop_name_201.jpg', [0, 0, 400, 387]),
#   ('crop_name_53.jpg', [0, 0, 400, 343]),
#   ('crop_name_0.jpg', [0, 0, 400, 402]),
#   ('crop_name_137.jpg', [179, 111, 241, 190]),
#   ('crop_name_94.jpg', [0, 0, 400, 438]),
#   ('crop_name_37.jpg', [0, 0, 400, 409]),
#   ('crop_name_188.jpg', [0, 0, 400, 376]),
#   ('crop_name_147.jpg', [0, 0, 400, 319]),
#   ('crop_name_31.jpg', [0, 0, 400, 326]),
#   ('crop_name_142.jpg', [0, 0, 400, 356]),
#   ('crop_name_179.jpg', [0, 0, 400, 426]),
#   ('crop_name_265.jpg', [0, 0, 400, 523]),
#   ('crop_name_258.jpg', [0, 0, 400, 440]),
#   ('crop_name_144.jpg', [0, 0, 400, 493]),
#   ('crop_name_307.jpg', [0, 61, 400, 438]),
#   ('crop_name_48.jpg', [0, 0, 400, 430]),
#   ('crop_name_305.jpg', [0, 0, 400, 473]),
#   ('crop_name_9.jpg', [0, 0, 400, 341]),
#   ('crop_name_195.jpg', [0, 0, 400, 436]),
#   ('crop_name_148.jpg', [143, 344, 203, 439])],
#  'image_name_73.jpg': [('crop_name_201.jpg', [0, 0, 400, 387]),
#   ('crop_name_117.jpg', [311, 372, 356, 441]),
#   ('crop_name_53.jpg', [0, 0, 400, 343]),
#   ('crop_name_0.jpg', [0, 0, 400, 402]),
#   ('crop_name_94.jpg', [0, 0, 400, 438]),
#   ('crop_name_37.jpg', [0, 0, 400, 409]),
#   ('crop_name_188.jpg', [0, 0, 400, 376]),
#   ('crop_name_147.jpg', [0, 0, 400, 319]),
#   ('crop_name_31.jpg', [0, 0, 400, 326]),
#   ('crop_name_306.jpg', [329, 92, 374, 160]),
#   ('crop_name_142.jpg', [0, 0, 400, 356]),
#   ('crop_name_179.jpg', [0, 0, 400, 426]),
#   ('crop_name_265.jpg', [0, 0, 400, 523]),
#   ('crop_name_258.jpg', [0, 0, 400, 440]),
#   ('crop_name_144.jpg', [0, 0, 400, 493]),
#   ('crop_name_307.jpg', [0, 108, 400, 485]),
#   ('crop_name_48.jpg', [0, 0, 400, 430]),
#   ('crop_name_305.jpg', [0, 0, 400, 473]),
#   ('crop_name_9.jpg', [0, 0, 400, 341]),
#   ('crop_name_195.jpg', [0, 0, 400, 436]),
#   ('crop_name_148.jpg', [137, 474, 188, 555])],
#  'image_name_3.jpg': [('crop_name_201.jpg', [0, 0, 400, 387]),
#   ('crop_name_117.jpg', [49, 218, 94, 287]),
#   ('crop_name_53.jpg', [0, 0, 400, 343]),
#   ('crop_name_0.jpg', [0, 0, 400, 402]),
#   ('crop_name_10.jpg', [248, 506, 310, 588]),
#   ('crop_name_139.jpg', [95, 46, 146, 157]),
#   ('crop_name_94.jpg', [0, 0, 400, 438]),
#   ('crop_name_37.jpg', [0, 0, 400, 409]),
#   ('crop_name_188.jpg', [0, 0, 400, 376]),
#   ('crop_name_147.jpg', [0, 0, 400, 319]),
#   ('crop_name_31.jpg', [0, 0, 400, 326]),
#   ('crop_name_142.jpg', [0, 0, 400, 356]),
#   ('crop_name_179.jpg', [0, 0, 400, 426]),
#   ('crop_name_265.jpg', [0, 0, 400, 523]),
#   ('crop_name_258.jpg', [0, 0, 400, 440]),
#   ('crop_name_144.jpg', [0, 0, 400, 493]),
#   ('crop_name_307.jpg', [0, 175, 400, 552]),
#   ('crop_name_48.jpg', [0, 0, 400, 430]),
#   ('crop_name_305.jpg', [0, 0, 400, 473]),
#   ('crop_name_287.jpg', [98, 297, 160, 370]),
#   ('crop_name_9.jpg', [0, 0, 400, 341]),
#   ('crop_name_195.jpg', [0, 0, 400, 436]),
#   ('crop_name_148.jpg', [174, 449, 225, 530])],
#  'image_name_129.jpg': [('crop_name_201.jpg', [0, 0, 400, 387]),
#   ('crop_name_53.jpg', [0, 0, 400, 343]),
#   ('crop_name_0.jpg', [0, 0, 400, 402]),
#   ('crop_name_137.jpg', [179, 111, 241, 190]),
#   ('crop_name_94.jpg', [0, 0, 400, 438]),
#   ('crop_name_37.jpg', [0, 0, 400, 409]),
#   ('crop_name_188.jpg', [0, 0, 400, 376]),
#   ('crop_name_147.jpg', [0, 0, 400, 319]),
#   ('crop_name_31.jpg', [0, 0, 400, 326]),
#   ('crop_name_142.jpg', [0, 0, 400, 356]),
#   ('crop_name_179.jpg', [0, 0, 400, 426]),
#   ('crop_name_265.jpg', [0, 0, 400, 523]),
#   ('crop_name_258.jpg', [0, 0, 400, 440]),
#   ('crop_name_144.jpg', [0, 0, 400, 493]),
#   ('crop_name_307.jpg', [0, 61, 400, 438]),
#   ('crop_name_48.jpg', [0, 0, 400, 430]),
#   ('crop_name_305.jpg', [0, 0, 400, 473]),
#   ('crop_name_9.jpg', [0, 0, 400, 341]),
#   ('crop_name_195.jpg', [0, 0, 400, 436]),
#   ('crop_name_148.jpg', [143, 344, 203, 439])],
#  'image_name_113.jpg': [('crop_name_201.jpg', [0, 0, 400, 387]),
#   ('crop_name_34.jpg', [118, 91, 277, 328]),
#   ('crop_name_30.jpg', [138, 224, 274, 358]),
#   ('crop_name_53.jpg', [0, 0, 400, 343]),
#   ('crop_name_0.jpg', [0, 0, 400, 402]),
#   ('crop_name_94.jpg', [0, 0, 400, 438]),
#   ('crop_name_37.jpg', [0, 0, 400, 409]),
#   ('crop_name_167.jpg', [192, 519, 254, 592]),
#   ('crop_name_188.jpg', [0, 0, 400, 376]),
#   ('crop_name_147.jpg', [0, 0, 400, 319]),
#   ('crop_name_31.jpg', [0, 0, 400, 326]),
#   ('crop_name_177.jpg', [150, 340, 266, 443]),
#   ('crop_name_142.jpg', [0, 0, 400, 356]),
#   ('crop_name_179.jpg', [0, 0, 400, 426]),
#   ('crop_name_265.jpg', [0, 0, 400, 523]),
#   ('crop_name_258.jpg', [0, 0, 400, 440]),
#   ('crop_name_144.jpg', [0, 0, 400, 493]),
#   ('crop_name_307.jpg', [5, 17, 349, 341]),
#   ('crop_name_48.jpg', [0, 0, 400, 430]),
#   ('crop_name_305.jpg', [0, 0, 400, 473]),
#   ('crop_name_9.jpg', [0, 0, 400, 341]),
#   ('crop_name_195.jpg', [0, 0, 400, 436]),
#   ('crop_name_148.jpg', [114, 401, 226, 578]),
#   ('crop_name_149.jpg', [174, 422, 259, 530])],
#  'image_name_117.jpg': [('crop_name_201.jpg', [0, 0, 400, 387]),
#   ('crop_name_53.jpg', [0, 0, 400, 343]),
#   ('crop_name_0.jpg', [0, 0, 400, 402]),
#   ('crop_name_94.jpg', [0, 0, 400, 438]),
#   ('crop_name_37.jpg', [0, 0, 400, 409]),
#   ('crop_name_188.jpg', [0, 0, 400, 376]),
#   ('crop_name_147.jpg', [0, 0, 400, 319]),
#   ('crop_name_42.jpg', [306, 292, 368, 362]),
#   ('crop_name_31.jpg', [0, 0, 400, 326]),
#   ('crop_name_306.jpg', [138, 403, 183, 471]),
#   ('crop_name_142.jpg', [0, 0, 400, 356]),
#   ('crop_name_179.jpg', [0, 0, 400, 426]),
#   ('crop_name_265.jpg', [0, 0, 400, 523]),
#   ('crop_name_258.jpg', [0, 0, 400, 440]),
#   ('crop_name_144.jpg', [0, 0, 400, 493]),
#   ('crop_name_307.jpg', [30, 4, 374, 328]),
#   ('crop_name_48.jpg', [0, 0, 400, 430]),
#   ('crop_name_305.jpg', [0, 0, 400, 473]),
#   ('crop_name_9.jpg', [0, 0, 400, 341]),
#   ('crop_name_195.jpg', [0, 0, 400, 436]),
#   ('crop_name_148.jpg', [117, 386, 168, 467]),
#   ('crop_name_133.jpg', [147, 308, 241, 514])],
#  'image_name_53.jpg': [('crop_name_201.jpg', [0, 0, 400, 387]),
#   ('crop_name
jpg': [('crop_name_201.jpg', [0, 0, 400, 387]),
#   ('crop_name_53.jpg', [0, 0, 400, 343]),
#   ('crop_name_0.jpg', [0, 0, 400, 402]),
#   ('crop_name_139.jpg', [313, 51, 373, 181]),
#   ('crop_name_137.jpg', [329, 296, 382, 363]),
#   ('crop_name_94.jpg', [0, 0, 400, 438]),
#   ('crop_name_37.jpg', [0, 0, 400, 409]),
#   ('crop_name_206.jpg', [9, 346, 58, 427]),
#   ('crop_name_188.jpg', [0, 0, 400, 376]),
#   ('crop_name_147.jpg', [0, 0, 400, 319]),
#   ('crop_name_31.jpg', [0, 0, 400, 326]),
#   ('crop_name_306.jpg', [47, 319, 92, 387]),
#   ('crop_name_79.jpg', [298, 46, 383, 142]),
#   ('crop_name_173.jpg', [170, 19, 306, 126]),
#   ('crop_name_209.jpg', [5, 343, 67, 428]),
#   ('crop_name_142.jpg', [0, 0, 400, 356]),
#   ('crop_name_179.jpg', [0, 0, 400, 426]),
#   ('crop_name_265.jpg', [0, 0, 400, 523]),
#   ('crop_name_258.jpg', [0, 0, 400, 440]),
#   ('crop_name_144.jpg', [0, 0, 400, 493]),
#   ('crop_name_307.jpg', [19, 2, 363, 326]),
#   ('crop_name_48.jpg', [0, 0, 400, 430]),
#   ('crop_name_305.jpg', [0, 0, 400, 473]),
#   ('crop_name_287.jpg', [7, 394, 69, 467]),
#   ('crop_name_9.jpg', [0, 0, 400, 341]),
#   ('crop_name_108.jpg', [2, 213, 64, 298]),
#   ('crop_name_195.jpg', [0, 0, 400, 436]),
#   ('crop_name_148.jpg', [16, 317, 86, 428])],
#  'image_name_87.jpg': [('crop_name_201.jpg', [0, 0, 400, 387]),
#   ('crop_name_53.jpg', [0, 0, 400, 343]),
#   ('crop_name_0.jpg', [0, 0, 400, 402]),
#   ('crop_name_94.jpg', [0, 0, 400, 438]),
#   ('crop_name_37.jpg', [0, 0, 400, 409]),
#   ('crop_name_188.jpg', [0, 0, 400, 376]),
#   ('crop_name_147.jpg', [0, 0, 400, 319]),
#   ('crop_name_31.jpg', [0, 0, 400, 326]),
#   ('crop_name_306.jpg', [3, 322, 48, 390]),
#   ('crop_name_142.jpg', [0, 0, 400, 356]),
#   ('crop_name_179.jpg', [0, 0, 400, 426]),
#   ('crop_name_265.jpg', [0, 0, 400, 523]),
#   ('crop_name_258.jpg', [0, 0, 400, 440]),
#   ('crop_name_144.jpg', [0, 0, 400, 493]),
#   ('crop_name_307.jpg', [0, 206, 400, 583]),
#   ('crop_name_48.jpg', [0, 0, 400, 430]),
#   ('crop_name_305.jpg', [0, 0, 400, 473]),
#   ('crop_name_9.jpg', [0, 0, 400, 341]),
#   ('crop_name_195.jpg', [0, 0, 400, 436]),
#   ('crop_name_148.jpg', [276, 264, 346, 375])],
#  'image_name_47.jpg': [('crop_name_201.jpg', [0, 0, 657, 636]),
#   ('crop_name_53.jpg', [0, 0, 657, 564]),
#   ('crop_name_0.jpg', [0, 0, 652, 657]),
#   ('crop_name_94.jpg', [0, 0, 599, 657]),
#   ('crop_name_37.jpg', [0, 0, 641, 657]),
#   ('crop_name_188.jpg', [0, 0, 657, 619]),
#   ('crop_name_147.jpg', [0, 0, 657, 525]),
#   ('crop_name_31.jpg', [0, 0, 657, 536]),
#   ('crop_name_142.jpg', [0, 0, 657, 585]),
#   ('crop_name_179.jpg', [0, 0, 528, 565]),
#   ('crop_name_265.jpg', [0, 0, 501, 657]),
#   ('crop_name_258.jpg', [0, 0, 596, 657]),
#   ('crop_name_144.jpg', [0, 0, 532, 657]),
#   ('crop_name_307.jpg', [0, 0, 657, 620]),
#   ('crop_name_48.jpg', [0, 0, 524, 565]),
#   ('crop_name_305.jpg', [0, 0, 477, 565]),
#   ('crop_name_9.jpg', [0, 0, 657, 560]),
#   ('crop_name_195.jpg', [0, 0, 601, 657])],
#  'image_name_106.jpg': [('crop_name_201.jpg', [0, 0, 400, 387]),
#   ('crop_name_157.jpg', [232, 367, 294, 462]),
#   ('crop_name_53.jpg', [0, 0, 400, 343]),
#   ('crop_name_0.jpg', [0, 0, 400, 402]),
#   ('crop_name_94.jpg', [0, 0, 400, 438]),
#   ('crop_name_37.jpg', [0, 0, 400, 409]),
#   ('crop_name_294.jpg', [124, 132, 283, 310]),
#   ('crop_name_188.jpg', [0, 0, 400, 376]),
#   ('crop_name_147.jpg', [0, 0, 400, 319]),
#   ('crop_name_42.jpg', [122, 4, 184, 74]),
#   ('crop_name_31.jpg', [0, 0, 400, 326]),
#   ('crop_name_306.jpg', [0, 380, 45, 448]),
#   ('crop_name_142.jpg', [0, 0, 400, 356]),
#   ('crop_name_179.jpg', [0, 0, 400, 426]),
#   ('crop_name_265.jpg', [0, 0, 400, 523]),
#   ('crop_name_258.jpg', [0, 0, 400, 440]),
#   ('crop_name_144.jpg', [0, 0, 400, 493]),
#   ('crop_name_307.jpg', [0, 92, 400, 469]),
#   ('crop_name_288.jpg', [164, 308, 242, 485]),
#   ('crop_name_48.jpg', [0, 0, 400, 430]),
#   ('crop_name_305.jpg', [0, 0, 400, 473]),
#   ('crop_name_287.jpg', [180, 261, 242, 334]),
#   ('crop_name_9.jpg', [0, 0, 400, 341]),
#   ('crop_name_195.jpg', [0, 0, 400, 436])],
#  'image_name_91.jpg': [('crop_name_201.jpg', [0, 0, 400, 387]),
#   ('crop_name_53.jpg', [0, 0, 400, 343]),
#   ('crop_name_0.jpg', [0, 0, 400, 402]),
#   ('crop_name_94.jpg', [0, 0, 400, 438]),
#   ('crop_name_37.jpg', [0, 0, 400, 409]),
#   ('crop_name_188.jpg', [0, 0, 400, 376]),
#   ('crop_name_147.jpg', [0, 0, 400, 319]),
#   ('crop_name_31.jpg', [0, 0, 400, 326]),
#   ('crop_name_142.jpg', [0, 0, 400, 356]),
#   ('crop_name_179.jpg', [0, 0, 400, 426]),
#   ('crop_name_265.jpg', [0, 0, 400, 523]),
#   ('crop_name_258.jpg', [0, 0, 400, 440]),
#   ('crop_name_144.jpg', [0, 0, 400, 493]),
#   ('crop_name_307.jpg', [11, 9, 355, 333]),
#   ('crop_name_48.jpg', [0, 0, 400, 430]),
#   ('crop_name_305.jpg', [0, 0, 400, 473]),
#   ('crop_name_287.jpg', [22, 272, 95, 357]),
#   ('crop_name_9.jpg', [0, 0, 400, 341]),
#   ('crop_name_195.jpg', [0, 0, 400, 436]),
#   ('crop_name_148.jpg', [53, 232, 104, 313])],
#  'image_name_46.jpg': [('crop_name_201.jpg', [0, 0, 400, 387]),
#   ('crop_name_53.jpg', [0, 0, 400, 343]),
#   ('crop_name_0.jpg', [0, 0, 400, 402]),
#   ('crop_name_94.jpg', [0, 0, 400, 438]),
#   ('crop_name_37.jpg', [0, 0, 400, 409]),
#   ('crop_name_188.jpg', [0, 0, 400, 376]),
#   ('crop_name_147.jpg', [0, 0, 400, 319]),
#   ('crop_name_262.jpg', [178, 127, 246, 279]),
#   ('crop_name_31.jpg', [0, 0, 400, 326]),
#   ('crop_name_306.jpg', [272, 195, 317, 263]),
#   ('crop_name_142.jpg', [0, 0, 400, 356]),
#   ('crop_name_179.jpg', [0, 0, 400, 426]),
#   ('crop_name_265.jpg', [0, 0, 400, 523]),
#   ('crop_name_258.jpg', [0, 0, 400, 440]),
#   ('crop_name_144.jpg', [0, 0, 400, 493]),
#   ('crop_name_307.jpg', [0, 102, 400, 479]),
#   ('crop_name_48.jpg', [0, 0, 400, 430]),
#   ('crop_name_305.jpg', [0, 0, 400, 473]),
#   ('crop_name_287.jpg', [184, 135, 246, 208]),
#   ('crop_name_9.jpg', [0, 0, 400, 341]),
#   ('crop_name_195.jpg', [0, 0, 400, 436]),
#   ('crop_name_148.jpg', [287, 84, 338, 165])],
#  'image_name_65.jpg': [('crop_name_201.jpg', [0, 0, 400, 387]),
#   ('crop_name_53.jpg', [0, 0, 400, 343]),
#   ('crop_name_0.jpg', [0, 0, 400, 402]),
#   ('crop_name_94.jpg', [0, 0, 400, 438]),
#   ('crop_name_37.jpg', [0, 0, 400, 409]),
#   ('crop_name_188.jpg', [0, 0, 400, 376]),
#   ('crop_name_147.jpg', [0, 0, 400, 319]),
#   ('crop_name_31.jpg', [0, 0, 400, 326]),
#   ('crop_name_142.jpg', [0, 0, 400, 356]),
#   ('crop_name_179.jpg', [0, 0, 400, 426]),
#   ('crop_name_265.jpg', [0, 0, 400, 523]),
#   ('crop_name_258.jpg', [0, 0, 400, 440]),
#   ('crop_name_144.jpg', [0, 0, 400, 493]),
#   ('crop_name_307.jpg', [44, 1, 388, 325]),
#   ('crop_name_48.jpg', [0, 0, 400, 430]),
#   ('crop_name_305.jpg', [0, 0, 400, 473]),
#   ('crop_name_9.jpg', [0, 0, 400, 341]),
#   ('crop_name_195.jpg', [0, 0, 400, 436])],
#  'image_name_42.jpg': [('crop_name_201.jpg', [0, 0, 400, 387]),
#   ('crop_name_53.jpg', [0, 0, 400, 343]),
#   ('crop_name_0.jpg', [0, 0, 400, 402]),
#   ('crop_name_94.jpg', [0, 0, 400, 438]),
#   ('crop_name_205.jpg', [112, 297, 185, 391]),
#   ('crop_name_37.jpg', [0, 0, 400, 409]),
#   ('crop_name_188.jpg', [0, 0, 400, 376]),
#   ('crop_name_147.jpg', [0, 0, 400, 319]),
#   ('crop_name_31.jpg', [0, 0, 400, 326]),
#   ('crop_name_306.jpg', [108, 222, 153, 290]),
#   ('crop_name_81.jpg', [154, 386, 207, 456]),
#   ('crop_name_142.jpg', [0, 0, 400, 356]),
#   ('crop_name_179.jpg', [0, 0, 400, 426]),
#   ('crop_name_265.jpg', [0, 0, 400, 523]),
#   ('crop_name_258.jpg', [0, 0, 400, 440]),
#   ('crop_name_144.jpg', [0, 0, 400, 493]),
#   ('crop_name_307.jpg', [18, 1, 362, 325]),
#   ('crop_name_48.jpg', [0, 0, 400, 430]),
#   ('crop_name_305.jpg', [0, 0, 400, 473]),
#   ('crop_name_72.jpg', [165, 124, 264, 228]),
#   ('crop_name_9.jpg', [0, 0, 400, 341]),
#   ('crop_name_195.jpg', [0, 0, 400, 436]),
#   ('crop_name_148.jpg', [134, 428, 185, 509])],
#  'image_name_62.jpg': [('crop_name_201.jpg', [0, 0, 400, 387]),
#   ('crop_name_53.jpg', [0, 0, 400, 343]),
#   ('crop_name_0.jpg', [0, 0, 400, 402]),
#   ('crop_name_94.jpg', [0, 0, 400, 438]),
#   ('crop_name_37.jpg', [0, 0, 400, 409]),
#   ('crop_name_188.jpg', [0, 0, 400, 376]),
#   ('crop_name_147.jpg', [0, 0, 400, 319]),
#   ('crop_name_31.jpg', [0, 0, 400, 326]),
#   ('crop_name_142.jpg', [0, 0, 400, 356]),
#   ('crop_name_179.jpg', [0, 0, 400, 426]),
#   ('crop_name_265.jpg', [0, 0, 400, 523]),
#   ('crop_name_258.jpg', [0, 0, 400, 440]),
#   ('crop_name_144.jpg', [0, 0, 400, 493]),
#   ('crop_name_307.jpg', [43, 2, 387, 326]),
#   ('crop_name_48.jpg', [0, 0, 400, 430]),
#   ('crop_name_305.jpg', [0, 0, 400, 473]),
#   ('crop_name_287.jpg', [173, 99, 235, 172]),
#   ('crop_name_9.jpg', [0, 0, 400, 341]),
#   ('crop_name_195.jpg', [0, 0, 400, 436]),
#   ('crop_name_123.jpg', [165, 321, 261, 527]),
#   ('crop_name_148.jpg', [117, 142, 168, 223])],
#  'image_name_141.jpg': [('crop_name_201.jpg', [0, 0, 543, 527]),
#   ('crop_name_53.jpg', [0, 0, 592, 509]),
#   ('crop_name_0.jpg', [0, 0, 523, 527]),
#   ('crop_name_94.jpg', [0, 0, 481, 527]),
#   ('crop_name_37.jpg', [0, 0, 514, 527]),
#   ('crop_name_188.jpg', [0, 0, 559, 527]),
#   ('crop_name_147.jpg', [0, 0, 592, 473]),
),
#   ('crop_name_9.jpg', [0, 0, 400, 341]),
#   ('crop_name_195.jpg', [0, 0, 400, 436]),
#   ('crop_name_148.jpg', [165, 339, 216, 420])],
#  'image_name_57.jpg': [('crop_name_201.jpg', [0, 0, 400, 387]),
#   ('crop_name_53.jpg', [0, 0, 400, 343]),
#   ('crop_name_0.jpg', [0, 0, 400, 402]),
#   ('crop_name_94.jpg', [0, 0, 400, 438]),
#   ('crop_name_37.jpg', [0, 0, 400, 409]),
#   ('crop_name_188.jpg', [0, 0, 400, 376]),
#   ('crop_name_147.jpg', [0, 0, 400, 319]),
#   ('crop_name_42.jpg', [270, 52, 332, 122]),
#   ('crop_name_262.jpg', [147, 177, 196, 288]),
#   ('crop_name_31.jpg', [0, 0, 400, 326]),
#   ('crop_name_306.jpg', [267, 183, 312, 251]),
#   ('crop_name_261.jpg', [190, 489, 235, 558]),
#   ('crop_name_142.jpg', [0, 0, 400, 356]),
#   ('crop_name_179.jpg', [0, 0, 400, 426]),
#   ('crop_name_265.jpg', [0, 0, 400, 523]),
#   ('crop_name_258.jpg', [0, 0, 400, 440]),
#   ('crop_name_43.jpg', [116, 85, 275, 300]),
#   ('crop_name_144.jpg', [0, 0, 400, 493]),
#   ('crop_name_307.jpg', [21, 0, 365, 324]),
#   ('crop_name_48.jpg', [0, 0, 400, 430]),
#   ('crop_name_305.jpg', [0, 0, 400, 473]),
#   ('crop_name_287.jpg', [140, 172, 202, 245]),
#   ('crop_name_9.jpg', [0, 0, 400, 341]),
#   ('crop_name_195.jpg', [0, 0, 400, 436]),
#   ('crop_name_148.jpg', [211, 407, 262, 488])],
#  'image_name_34.jpg': [('crop_name_201.jpg', [0, 0, 522, 505]),
#   ('crop_name_53.jpg', [0, 0, 522, 448]),
#   ('crop_name_0.jpg', [0, 0, 522, 525]),
#   ('crop_name_94.jpg', [0, 0, 522, 571]),
#   ('crop_name_37.jpg', [0, 0, 522, 534]),
#   ('crop_name_188.jpg', [0, 0, 522, 491]),
#   ('crop_name_147.jpg', [0, 0, 522, 417]),
#   ('crop_name_31.jpg', [0, 0, 522, 426]),
#   ('crop_name_142.jpg', [0, 0, 448, 399]),
#   ('crop_name_179.jpg', [0, 0, 522, 556]),
#   ('crop_name_265.jpg', [0, 0, 522, 683]),
#   ('crop_name_258.jpg', [0, 0, 522, 574]),
#   ('crop_name_144.jpg', [0, 0, 522, 644]),
#   ('crop_name_307.jpg', [0, 0, 522, 492]),
#   ('crop_name_48.jpg', [0, 0, 522, 561]),
#   ('crop_name_305.jpg', [0, 0, 522, 617]),
#   ('crop_name_9.jpg', [0, 0, 522, 445]),
#   ('crop_name_195.jpg', [0, 0, 522, 570])],
#  'na': [('crop_name_189.jpg', []),
#   ('crop_name_275.jpg', []),
#   ('crop_name_301.jpg', []),
#   ('crop_name_36.jpg', []),
#   ('crop_name_161.jpg', []),
#   ('crop_name_202.jpg', []),
#   ('crop_name_99.jpg', []),
#   ('crop_name_289.jpg', []),
#   ('crop_name_118.jpg', []),
#   ('crop_name_187.jpg', []),
#   ('crop_name_254.jpg', []),
#   ('crop_name_217.jpg', []),
#   ('crop_name_286.jpg', []),
#   ('crop_name_64.jpg', []),
#   ('crop_name_107.jpg', []),
#   ('crop_name_22.jpg', []),
#   ('crop_name_145.jpg', []),
#   ('crop_name_65.jpg', []),
#   ('crop_name_278.jpg', []),
#   ('crop_name_16.jpg', []),
#   ('crop_name_260.jpg', []),
#   ('crop_name_203.jpg', []),
#   ('crop_name_17.jpg', []),
#   ('crop_name_138.jpg', []),
#   ('crop_name_178.jpg', []),
#   ('crop_name_119.jpg', []),
#   ('crop_name_11.jpg', []),
#   ('crop_name_309.jpg', []),
#   ('crop_name_263.jpg', []),
#   ('crop_name_234.jpg', []),
#   ('crop_name_39.jpg', []),
#   ('crop_name_299.jpg', []),
#   ('crop_name_115.jpg', []),
#   ('crop_name_230.jpg', []),
#   ('crop_name_32.jpg', []),
#   ('crop_name_96.jpg', []),
#   ('crop_name_266.jpg', []),
#   ('crop_name_219.jpg', []),
#   ('crop_name_46.jpg', []),
#   ('crop_name_241.jpg', []),
#   ('crop_name_227.jpg', []),
#   ('crop_name_63.jpg', []),
#   ('crop_name_35.jpg', []),
#   ('crop_name_153.jpg', []),
#   ('crop_name_29.jpg', []),
#   ('crop_name_192.jpg', []),
#   ('crop_name_27.jpg', []),
#   ('crop_name_57.jpg', []),
#   ('crop_name_308.jpg', []),
#   ('crop_name_91.jpg', []),
#   ('crop_name_151.jpg', []),
#   ('crop_name_84.jpg', []),
#   ('crop_name_240.jpg', []),
#   ('crop_name_15.jpg', []),
#   ('crop_name_132.jpg', []),
#   ('crop_name_251.jpg', []),
#   ('crop_name_298.jpg', []),
#   ('crop_name_292.jpg', []),
#   ('crop_name_248.jpg', []),
#   ('crop_name_236.jpg', []),
#   ('crop_name_38.jpg', []),
#   ('crop_name_168.jpg', []),
#   ('crop_name_25.jpg', []),
#   ('crop_name_135.jpg', []),
#   ('crop_name_146.jpg', []),
#   ('crop_name_101.jpg', []),
#   ('crop_name_76.jpg', []),
#   ('crop_name_69.jpg', []),
#   ('crop_name_208.jpg', []),
#   ('crop_name_49.jpg', []),
#   ('crop_name_28.jpg', []),
#   ('crop_name_105.jpg', []),
#   ('crop_name_14.jpg', []),
#   ('crop_name_128.jpg', []),
#   ('crop_name_256.jpg', []),
#   ('crop_name_237.jpg', []),
#   ('crop_name_50.jpg', []),
#   ('crop_name_183.jpg', []),
#   ('crop_name_210.jpg', []),
#   ('crop_name_270.jpg', []),
#   ('crop_name_170.jpg', []),
#   ('crop_name_276.jpg', []),
#   ('crop_name_5.jpg', []),
#   ('crop_name_302.jpg', []),
#   ('crop_name_283.jpg', []),
#   ('crop_name_211.jpg', []),
#   ('crop_name_184.jpg', []),
#   ('crop_name_140.jpg', []),
#   ('crop_name_6.jpg', []),
#   ('crop_name_58.jpg', []),
#   ('crop_name_54.jpg', []),
#   ('crop_name_291.jpg', []),
#   ('crop_name_162.jpg', []),
#   ('crop_name_62.jpg', []),
#   ('crop_name_242.jpg', []),
#   ('crop_name_235.jpg', []),
#   ('crop_name_97.jpg', []),
#   ('crop_name_40.jpg', []),
#   ('crop_name_160.jpg', []),
#   ('crop_name_13.jpg', []),
#   ('crop_name_213.jpg', []),
#   ('crop_name_238.jpg', []),
#   ('crop_name_109.jpg', []),
#   ('crop_name_121.jpg', []),
#   ('crop_name_24.jpg', []),
#   ('crop_name_52.jpg', []),
#   ('crop_name_134.jpg', []),
#   ('crop_name_295.jpg', []),
#   ('crop_name_59.jpg', []),
#   ('crop_name_88.jpg', []),
#   ('crop_name_77.jpg', []),
#   ('crop_name_98.jpg', []),
#   ('crop_name_74.jpg', []),
#   ('crop_name_158.jpg', []),
#   ('crop_name_196.jpg', []),
#   ('crop_name_131.jpg', []),
#   ('crop_name_78.jpg', []),
#   ('crop_name_214.jpg', []),
#   ('crop_name_221.jpg', []),
#   ('crop_name_220.jpg', []),
#   ('crop_name_23.jpg', []),
#   ('crop_name_267.jpg', []),
#   ('crop_name_112.jpg', []),
#   ('crop_name_271.jpg', []),
#   ('crop_name_70.jpg', []),
#   ('crop_name_129.jpg', []),
#   ('crop_name_166.jpg', []),
#   ('crop_name_102.jpg', []),
#   ('crop_name_222.jpg', []),
#   ('crop_name_255.jpg', []),
#   ('crop_name_268.jpg', []),
#   ('crop_name_300.jpg', []),
#   ('crop_name_225.jpg', []),
#   ('crop_name_245.jpg', []),
#   ('crop_name_239.jpg', []),
#   ('crop_name_127.jpg', []),
#   ('crop_name_257.jpg', []),
#   ('crop_name_47.jpg', []),
#   ('crop_name_172.jpg', []),
#   ('crop_name_66.jpg', []),
#   ('crop_name_68.jpg', []),
#   ('crop_name_175.jpg', []),
#   ('crop_name_232.jpg', []),
#   ('crop_name_56.jpg', []),
#   ('crop_name_274.jpg', []),
#   ('crop_name_252.jpg', []),
#   ('crop_name_95.jpg', []),
#   ('crop_name_113.jpg', []),
#   ('crop_name_249.jpg', []),
#   ('crop_name_26.jpg', []),
#   ('crop_name_212.jpg', []),
#   ('crop_name_303.jpg', []),
#   ('crop_name_273.jpg', []),
#   ('crop_name_92.jpg', []),
#   ('crop_name_141.jpg', []),
#   ('crop_name_247.jpg', []),
#   ('crop_name_186.jpg', []),
#   ('crop_name_253.jpg', []),
#   ('crop_name_198.jpg', []),
#   ('crop_name_55.jpg', []),
#   ('crop_name_174.jpg', []),
#   ('crop_name_297.jpg', []),
#   ('crop_name_19.jpg', []),
#   ('crop_name_4.jpg', []),
#   ('crop_name_215.jpg', []),
#   ('crop_name_136.jpg', []),
#   ('crop_name_164.jpg', []),
#   ('crop_name_116.jpg', []),
#   ('crop_name_104.jpg', []),
#   ('crop_name_171.jpg', []),
#   ('crop_name_126.jpg', []),
#   ('crop_name_180.jpg', []),
#   ('crop_name_293.jpg', []),
#   ('crop_name_282.jpg', []),
#   ('crop_name_207.jpg', []),
#   ('crop_name_90.jpg', []),
#   ('crop_name_80.jpg', []),
#   ('crop_name_114.jpg', []),
#   ('crop_name_155.jpg', []),
#   ('crop_name_61.jpg', []),
#   ('crop_name_204.jpg', []),
#   ('crop_name_71.jpg', []),
#   ('crop_name_244.jpg', []),
#   ('crop_name_246.jpg', [])]}
